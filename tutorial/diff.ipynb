# %%
#%pip3 install text-fabric
#%pip3 install textanalysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tfa.diff import collectDiffs

# %% [markdown]
# # Systematic differences
#
# We look at the systematic differences between words.
#
# The idea is that if the same difference occurs between various word pairs, we have a morphological
# relationship between the pair.
#
# We load the corpus.

# %%
# A = use("Nino-cunei/oldbabylonian:clone", checkout="clone", hoist=globals())
A = use("Nino-cunei/oldbabylonian", hoist=globals())
# Out:
# <b title="local commit">TF-app:</b> <span title="#112043cfaac7d50d5398025c71cd916a80b854df offline under ~/text-fabric-data">~/text-fabric-data/Nino-cunei/oldbabylonian/app</span>
# <b title="local release">data:</b> <span title="rv1.6=#70b9c4893ede4bfe5ee1b92b37551693e79e9c78 offline under ~/text-fabric-data">~/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.6</span>
# This is Text-Fabric 9.2.2
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 67 features found and 0 ignored
# ...

# %% [markdown]
# # Collect
#
# We collect the differences between pairs of words.

# %%
D = collectDiffs(A, "word", "symr", frequencyThreshold=3, sizeThreshold=4)
# Out:
# 76505 word occurrences of 16131 distinct words
# 2545 common words
# Computing 3237240 comparisons
#   3237240 = 100 %
# Stored 252383 word pairs between 2473 words
# Computing 252383 diffs between word pairs
#    252383 = 100 %
# 242593 distinct differences

# %% [markdown]
# Here are the top-100 differences.

# %%
D.showDiffs(0, 100)
# Out:
# seq | freq | `-` | `+` | examples
# --- | ---  | --- | --- | ---
# *1* | **161** | ` ` | `-ma)` | ARAD-ka `~` ARAD-ka-ma ` ` a-ha-at-ka `~` a-ha-at-ka-ma ` ` a-hu-ka `~` a-hu-ka-ma
# *2* | **49** | ` ` | `-ka)` | ARAD `~` ARAD-ka ` ` a-ah `~` a-ah-ka ` ` a-bi `~` a-bi-ka
# *3* | **49** | `a` | `i` | a-ba-šu `~` a-bi-šu ` ` a-ha-šu `~` a-hi-šu ` ` a-hu-ka-ma `~` a-hu-ki-ma
# *4* | **47** | ` ` | `-ia)` | a-bi `~` a-bi-ia ` ` a-ha-ti `~` a-ha-ti-ia ` ` a-hi `~` a-hi-ia
# *5* | **47** | ` ` | `m)` | a-an-na `~` a-an-nam ` ` a-la-ka `~` a-la-kam ` ` a-li `~` a-lim
# *6* | **39** | `(a` | `(i` | a-da-ab-bu-ub `~` i-da-ab-bu-ub ` ` a-di `~` i-di ` ` a-la-ak `~` i-la-ak
# *7* | **38** | ` ` | `-šu)` | a-ba `~` a-ba-šu ` ` a-bi `~` a-bi-šu ` ` a-hi `~` a-hi-šu
# *8* | **37** | `-a` | ` ` | a-an-na `~` an-na ` ` a-an-na-am `~` a-an-nam ` ` a-la-ka-am `~` a-la-kam
# *9* | **35** | ` ` | `-im)` | a-hi `~` a-hi-im ` ` a-la-ki `~` a-la-ki-im ` ` a-li `~` a-li-im
# ...
